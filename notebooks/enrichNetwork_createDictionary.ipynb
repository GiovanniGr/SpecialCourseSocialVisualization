# %% [markdown]
# # Enrich the networks with the statistics, save them also in a dictionary

# %%
import networkx as nx
from fa2 import ForceAtlas2  #the package should be installed before
import matplotlib.pyplot as plt
from datetime import datetime
from statistics import mean, median, quantiles
from networkx.algorithms.traversal.breadth_first_search import descendants_at_distance
import time
import requests
import glob
import pickle
import os
import shutil

# %%
def addAuthorFeatures(G, feat_dict, num_comm):
    #Author-network characteristics
    undir_authorGraph = G.to_undirected()
    authorGraph_NoRoot = G.copy()
    authorGraph_NoRoot.remove_node(list(G.nodes())[0])
    undirect_authorGraph_NoRoot = authorGraph_NoRoot.to_undirected()
    cc_aux = list(nx.weakly_connected_components(authorGraph_NoRoot))
    if len(cc_aux) == 0:
        size_largest_conn_comp = 0
        diam = 0
        recip_value = 0
        clust_coeff  = 0
    else:
        largest_cc_authorGraph = authorGraph_NoRoot.subgraph(max(nx.weakly_connected_components(authorGraph_NoRoot), key=len))
        undir_largest_cc_authorGraph = largest_cc_authorGraph.to_undirected()
        
        size_largest_conn_comp = len(largest_cc_authorGraph)
        diam = nx.algorithms.distance_measures.diameter(undir_largest_cc_authorGraph)
        recip_value = nx.algorithms.reciprocity(G)
        clust_coeff = nx.average_clustering(undir_authorGraph)

    num_users = G.number_of_nodes()
    num_edges = G.number_of_edges()
    
    G.graph["num_users"] = num_users/num_comm
    G.graph["num_edges"] = num_edges/num_comm
    G.graph["size_largest_conn_comp"] = size_largest_conn_comp/num_comm
    G.graph["recip_value"] = recip_value/num_comm
    G.graph["diam"] = diam/num_comm
    G.graph["clust_coeff"] = clust_coeff/num_comm
    
    feat_dict["authorStats"]["num_users"] = float(num_users)/num_comm
    feat_dict["authorStats"]["num_edges"] = float(num_edges)/num_comm
    feat_dict["authorStats"]["size_largest_conn_comp"] = float(size_largest_conn_comp)/num_comm
    feat_dict["authorStats"]["recip_value"] = recip_value/num_comm
    feat_dict["authorStats"]["diam"] = float(diam)/num_comm
    feat_dict["authorStats"]["clust_coeff"] = clust_coeff/num_comm

# %%
def comments_and_max_depth_and_H_index(G):
    i=0
    dir_comments = len(descendants_at_distance(G, list(G.nodes())[0], 1))
    num_comments = G.number_of_nodes()
    descs = [len(descendants_at_distance(G, list(G.nodes())[0], i))]
    while descs[-1] > 0:
        i = i+1
        descs.append(len(descendants_at_distance(G, list(G.nodes())[0], i)))
    
    for j in range(len(descs)):
        if descs[j] < j:
            return num_comments, dir_comments, i, j

# %%
def addCommentsFeatures(G, feat_dict, norma):
    #Temporal patterns
    created_utcs1=list(nx.get_node_attributes(G,'created').values())
    if len(G)>2:
        lifeTime = max(created_utcs1)-min(created_utcs1)
        averageTime = mean(created_utcs1)-min(created_utcs1)
        medianTime = median(created_utcs1)-min(created_utcs1)
        quantiles95 = quantiles(created_utcs1,n=10)[8]
        lifetime95 = quantiles95-min(created_utcs1)
        
    else:
        lifeTime = 0
        averageTime = 0
        medianTime = 0
        lifetime95 = 0
        
    #Submission specific characteristics
    par = comments_and_max_depth_and_H_index(G)
    num_comm = par[0]
    if norma == False:
        num_comm = 1
    
    G.graph["lifeTime"] = lifeTime/num_comm
    G.graph["averageTime"] = averageTime/num_comm
    G.graph["medianTime"] = medianTime/num_comm
    G.graph["lifetime95"] = lifetime95/num_comm
    
    G.graph["num_comments"] = par[0]/num_comm
    G.graph["num_direct_comments"] = par[1]/num_comm
    G.graph["max_depth"] = par[2]/num_comm
    G.graph["H_index"] = par[3]/num_comm
    
    G.graph["created"] = list(nx.get_node_attributes(G,'created').values())[0]
    
    feat_dict["timeStats"]["lifeTime"] = lifeTime/num_comm
    feat_dict["timeStats"]["averageTime"] = averageTime/num_comm
    feat_dict["timeStats"]["medianTime"] = medianTime/num_comm
    feat_dict["timeStats"]["lifetime95"] = lifetime95/num_comm
    
    feat_dict["commStats"]["num_comments"] = par[0]/num_comm
    feat_dict["commStats"]["num_direct_comments"] = par[1]/num_comm
    feat_dict["commStats"]["max_depth"] = par[2]/num_comm
    feat_dict["commStats"]["H_index"] = par[3]/num_comm
    
    feat_dict["created"] = list(nx.get_node_attributes(G,'created').values())[0]
    #print(par[0])
    
    return num_comm

# %%
'''
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
'''
subreddit = "PoliticalDiscussion"

'''
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
'''




normals = [False]#, True]
for normal in normals:
    statCov = {}
    source_subfolder = "total"
    subfolder = "total"
    if normal==True:
        subfolder = "total_normalizedNumComm"
    
    shutil.rmtree("aG_enrich_monthly_"+subreddit+"/"+subfolder)
    os.mkdir("aG_enrich_monthly_"+subreddit+"/"+subfolder)
    
    comNets = glob.glob("cG_prove_monthly_"+subreddit+"/"+source_subfolder+"/*")
    for i,net in enumerate(comNets):
        if i%500 == 0:
            print(i,"/",len(comNets))
        netId = "t3_"+net.split("_")[5]
        statCov[netId] = {"authorStats":{},"timeStats":{},"commStats":{}}

        commentsGraph = nx.read_gpickle(net)
        num_comm = addCommentsFeatures(commentsGraph, statCov[netId], normal)

        nx.write_gpickle(commentsGraph,"cG_enrich_monthly_"+subreddit+"/"+subfolder+"/commGraph_"+netId+"_"+subreddit)

        authorGraph = nx.read_gpickle("aG_prove_monthly_"+subreddit+"/"+source_subfolder+"/aGraph_"+netId+"_"+subreddit)
        addAuthorFeatures(authorGraph, statCov[netId], num_comm)

        nx.write_gpickle(authorGraph,"aG_enrich_monthly_"+subreddit+"/"+subfolder+"/aGraph_"+netId+"_"+subreddit)

    with open('stat_'+subreddit+'_'+subfolder+'.pickle', 'wb') as handle:
        pickle.dump(statCov, handle)
# Out:
# 0 / 16652
# 500 / 16652
# 1000 / 16652
# 1500 / 16652
# 2000 / 16652
# 2500 / 16652
# 3000 / 16652
# 3500 / 16652
# 4000 / 16652
# 4500 / 16652
# 5000 / 16652
# 5500 / 16652
# 6000 / 16652
# 6500 / 16652
# 7000 / 16652
# 7500 / 16652
# 8000 / 16652
# 8500 / 16652
# 9000 / 16652
# 9500 / 16652
# 10000 / 16652
# 10500 / 16652
# 11000 / 16652
# 11500 / 16652
# 12000 / 16652
# 12500 / 16652
# 13000 / 16652
# 13500 / 16652
# 14000 / 16652
# 14500 / 16652
# 15000 / 16652
# 15500 / 16652
# 16000 / 16652
# 16500 / 16652

# %%
autNets = glob.glob("cg_"+subreddit+"/*")

# %%
autNets
# Out:
# ['cg_PoliticalDiscussion/cGraph_paf9du_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p9ipq2_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p6tr0x_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpz9qzw_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p7cjrg_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq1ekjh_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq031nz_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_phe627_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpw1dmw_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpzhqkd_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pla5rw_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pdef00_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pm6l4w_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pjb4k5_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pqf2ad_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_phyigb_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p6bt2m_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pcayfd_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq46z7q_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pgcxeu_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pqogy6_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p
PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq3hx5e_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_prfr3b_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pdovyy_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_phta5u_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pof7an_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pg3ns8_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_plxy2j_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphptf7kd_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpy184h_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pn08ns_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpy8wgs_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpxxes4_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpxgu93_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq01661_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pmkv4h_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_plzckz_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pm0bir_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p7qaul_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpv8685_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq0g4pz_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p9pmhv_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_ppvtyx_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_phvq9c_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p71pj0_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pir6lr_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq1v0x7_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpzd301_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpsk46o_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pmcpw5_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pdhl98_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq08ozq_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpvxfag_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pmgr93_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphptunwm_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_premp0_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pqwbp8_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpuuarg_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p6cjvj_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p9fu2x_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_ppnbrt_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pa6tdi_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p7vu8n_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pi938u_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpuvg8b_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_phmku1_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pqv39a_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p6k8oy_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpxg4lv_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphprywqc_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p9fvdu_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pgejut_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpv02ti_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pdyam0_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_prcglg_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pe5rpe_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pm9xda_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq08e20_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pmj4op_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphps1yab_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpywhke_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p6y4fr_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpzc7ha_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pqean7_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pmempy_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_phrs6w_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pnkkep_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pbv1c2_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pb1tud_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p67lgj_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpvnkpa_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p99h6o_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpxlzn1_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pj60km_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pf7vl2_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_poh2u9_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq409vd_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pjaqln_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pkus7p_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pm8mth_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pnl2ty_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_phqqiv_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pqa2d8_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpyrqta_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p9nngs_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_piodcl_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pfws4l_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pjumfr_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_phmyf0_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pbs63o_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq2y2nj_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p8baz7_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pqn0bs_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpuqo41_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pem912_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq16h5t_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pf35vi_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pa37st_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pgpztt_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_plv04x_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p87560_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p8ghds_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pes7oj_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpxwozh_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pkud02_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p6imdz_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pknlpi_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq4e19z_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pajnvw_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_ppjm4z_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_piqh5m_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpyub1k_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq10ria_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pd3ksc_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pgq9yu_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pgvlmf_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p8ygqe_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq3djd9_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpssequ_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p6inci_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpuwp3o_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pg9gk4_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq23asa_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p6c3p5_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_plmx8w_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pr0zww_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pfiem1_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_plq3p0_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pn8s6c_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpsbzfo_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphpspic8_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p77i7d_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq3sifc_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pcyzos_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pf333k_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pcs3gh_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p88mio_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pc7ou2_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pjpvvs_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_pl2o3p_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraphq08z4j_PoliticalDiscussion',
#  'cg_PoliticalDiscussion/cGraph_p6i76t_PoliticalDiscussion',
#  ...]

# %%
for net in autNets:
    authorGraph = nx.read_gpickle(net)
    name_aux = net.split("_")
    name = "cg_PoliticalDiscussion/cGraph"+name_aux[3]+"_PoliticalDiscussion"
    nx.write_gpickle(authorGraph,name)

# %%
import os
for net in autNets:
    os.remove(net)

# %%
len(autNets)
# Out:
# 1426

# %%
#all the subreddits at once
'''
subReddits = ["COVID19", "politics", "LGBTQ"]
allStatistics = {}
for subReddit in subReddits:
    autNets = glob.glob("aG/*_"+subReddit+"_*")
    if subReddit not in allStatistics:
        allStatistics[subReddit]={}
    for net in autNets:
        netId = net.split("_")[1]
        allStatistics[subReddit][netId] = {"authorStats":{},"timeStats":{},"commStats":{}}
        authorGraph = nx.read_gpickle(net)
        addAuthorFeatures(authorGraph, allStatistics[subReddit][netId])
        nx.write_gpickle(authorGraph,"enrich_authorGraphs/autGraph_"+netId+"_"+subReddit)
    
    comNets = glob.glob("commentsGraphs/*_"+subReddit)
    for net in comNets:
        netId = net.split("_")[1]
        commentsGraph = nx.read_gpickle(net)
        addCommentsFeatures(commentsGraph, allStatistics[subReddit][netId])
        nx.write_gpickle(commentsGraph,"enrich_commGraphs/commGraph_"+netId+"_"+subReddit)



with open('allStatistics_1.pickle', 'wb') as handle:
    pickle.dump(allStatistics, handle)

#with open('filename.pickle', 'rb') as handle:
#    b = pickle.load(handle)
'''
